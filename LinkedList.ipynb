# %% [markdown]
# # Linked List
#
# - Tips:
#     - dummy node: node(-1)

# %% [markdown]
# ## SingleLinkedList

# %%
class Node:
    
    def __init__(self,val):
        self.val = val
        self.next = None

class SingleLinkedList:
    
    def __init__(self):
        self.head = None
        self.tail = None
    
    def insert_node(self,head,val):
        node = Node(val)
        
        if head is None:
            self.head = node
        else:            
            if self.tail:
                self.tail.next = node
        
        self.tail = node
    
    def delete_node(self,val):
        
        if val == self.head.val:
            self.head = self.head.next
            return
        
        curr = self.head
        while curr.next:            
            if curr.next.val == val:
                break
            else:
                curr = curr.next
            
        
        next_node = curr.next.next
        curr.next = next_node
        return
          
    
def print_linkedlist(head):
    
    if not head:
        return []
    
    arr = []
    current = head
    while current:
        arr.append(current.val)
        current = current.next
    return arr

# %%
# test delete node

if __name__ == '__main__':
    arr = [1,2,3,4,5]
    n = len(arr)
    
    slist = SingleLinkedList()
    for a in arr:
        slist.insert_node(slist.head,a)
    
        
    ans = print_linkedlist(slist.head)
    print(ans)
    
    slist.delete_node(3)
    
    ans = print_linkedlist(slist.head)
    print(ans)
# Out:
# [1, 2, 3, 4, 5]
# [1, 2, 4, 5]

# %% [markdown]
# ## Easy

# %% [markdown]
# ## 83. Remove Duplicates from Sorted List
#
# ```
# Given a sorted linked list, delete all duplicates such that each element appear only once.
#
# Example 1:
#
# Input: 1->1->2
# Output: 1->2
# Example 2:
#
# Input: 1->1->2->3->3
# Output: 1->2->3
#
# ```

# %%
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, x):
#         self.val = x
#         self.next = None

class Solution:
    def deleteDuplicates(self, head):
        if not head:
            return
        
        curr = head
        while curr.next:
            if curr.val == curr.next.val:
                next_node = curr.next.next
                curr.next = next_node
            else:
                curr = curr.next
        return head

# %%
# test delete node

if __name__ == '__main__':
    arr = [1,1,2,2,3,4,5]
    n = len(arr)
    
    slist = SingleLinkedList()
    for a in arr:
        slist.insert_node(slist.head,a)
      
    ans = print_linkedlist(slist.head)
    print(ans)
    
    head = Solution().deleteDuplicates(slist.head)
    
    ans = print_linkedlist(head)
    print(ans)
# Out:
# [1, 1, 2, 2, 3, 4, 5]
# [1, 2, 3, 4, 5]

# %% [markdown]
# ### 21. Merge Two Sorted Lists
#
# ```
# Merge two sorted linked lists and return it as a new list. The new list should be made by splicing together the nodes of the first two lists.
#
# Example:
#
# Input: 1->2->4, 1->3->4
# Output: 1->1->2->3->4->4
# ```

# %%
class Solution(object):
    def mergeTwoLists(self, l1, l2):
        """
        :type l1: ListNode
        :type l2: ListNode
        :rtype: ListNode
        """
        
        if not l1 and not l2:
            return None
        elif (not l1) and l2:
            return l2
        elif (not l2) and l1:
            return l1
        
        dummy = Node(-1)
        cur = dummy
        
        while l1 and l2:
            if l1.data <= l2.data:
                cur.next = l1
                l1 = l1.next                 
            else:
                cur.next = l2
                l2 = l2.next
            cur = cur.next
        
        if l1:
            cur.next = l1
        if l2:
            cur.next = l2
        
        return dummy.next

# %%
if __name__ == '__main__':
    arr1 = [1,2,4]
    arr2 = [1,3,4]
    n = len(arr1)
    
    slist1 = SingleLinkedList()
    slist2 = SingleLinkedList()
    for a in arr1:
        slist1.insert_node(slist1.head,a)
    
    for b in arr2:
        slist2.insert_node(slist2.head,b)
       
    obj = Solution()
    merge = obj.mergeTwoLists(slist1.head,slist2.head)
    ans = print_linkedlist(merge)
    print(ans)
# Out:
# [1, 1, 2, 3, 4, 4]

# %% [markdown]
# ### 160. Intersection of Two Linked Lists

# %%
class Solution(object):
    def getIntersectionNode(self, headA, headB):
        """
        :type head1, head1: ListNode
        :rtype: ListNode
        """
        a = headA
        b = headB
        while a != b:
            a = a.next if a.next else headB
            b = b.next if b.next else headA
        return a.val

# %% [markdown]
# ### 206. Reverse Linked List
#
# - reverse single is harder than double

# %%
# cut the list into two part, reverse first part , then continue.
def reverseList(head):
    
    prev = None
    current = head
    
    while current:
        next_node = current.next
        current.next = prev
        prev = current
        current = next_node
    
    return prev

# %%
if __name__ == '__main__':
    arr = [1,2,3,4,5]
    n = len(arr)
    
    slist = SingleLinkedList()
    for a in arr:
        slist.insert_node(slist.head,a)
    
    rhead = reverseList(slist.head) 
    ans = print_linkedlist(rhead)
    print(ans)
# Out:
# [5, 4, 3, 2, 1]

# %% [markdown]
# ### Find Merge Point of Two Lists
# - arrive the merge point at same iteration time.
#
# ```
# a:1->2->6->7
# b:3->4->5->6->7
#
# merger point:6
# la = l(1,2) = 2,lb= l(3,4,5) = 3, lc = l(6,7) = 2
# so for a, l(1,2) + l(6,7) + l(3,4,5)
# for b, l(3,4,5) + l(6,7) + l(1,2).
# They traverse same distance and get same point
# ```

# %%
def findMergeNode(head1, head2):
    a= head1
    b= head2
    

    while a != b:
        
        # if "a" not "a.next"
        a = a.next if a else headB
        b = b.next if b else headA            
    return a

# %% [markdown]
# ### [ ] Reverse a doubly linked list

# %%
class DoublyLinkedListNode:
    def __init__(self, node_data):
        self.data = node_data
        self.next = None
        self.prev = None

class DoublyLinkedList:
    def __init__(self):
        self.head = None
        self.tail = None

    def insert_node(self, node_data):
        node = DoublyLinkedListNode(node_data)

        if not self.head:
            self.head = node
        else:
            self.tail.next = node
            node.prev = self.tail


        self.tail = node

def print_doubly_linked_list(node):
    while node:
        print(node.data)
        node = node.next
    return

# def reverse(head):
    
#     if not head:
#         return None
    
#     if not head.next:
#         return head    
    
#     former = head
#     latter = head.next    
#     while latter:
#         latter.prev = former.prev
#         former.next = latter.next
#         latter.next = former
#         former.prev = latter
        
#         head = former
#         latter = former.
    
#     return head

def reverse(head):
    result = head

    while head is not None:
        # exchange the self next and prev,
        head.prev, head.next = head.next, head.prev
        result = head
        head = head.prev

    return result

# %%
if __name__ == '__main__':

    t = 1

    for t_itr in range(t):
        llist_count = 2

        llist = DoublyLinkedList()
        
        #arr = [1,3,4,10]
        arr = [2,3]
        for i in range(llist_count):
            llist_item = arr[i]
            llist.insert_node(llist_item)

        #data = 1

        llist1 = reverse(llist.head)

        print_doubly_linked_list(llist1)

# %% [markdown]
# ###  Inserting a Node Into a Sorted Doubly Linked List
# - Four situations:
#     - not head
#     - target is head
#     - target is middle
#     - target is tail

# %%
class DoublyLinkedListNode:
    def __init__(self, node_data):
        self.data = node_data
        self.next = None
        self.prev = None

class DoublyLinkedList:
    def __init__(self):
        self.head = None
        self.tail = None

    def insert_node(self, node_data):
        node = DoublyLinkedListNode(node_data)

        if not self.head:
            self.head = node
        else:
            self.tail.next = node
            node.prev = self.tail


        self.tail = node
        
def print_doubly_linked_list(node):
    while node:
        print(node.data)

        node = node.next


def sortedInsert(head, data):
    node = DoublyLinkedListNode(data)
    
    
    # for no head
    if not head:
        head = node
        return head
    
    #for insert place is head
    if data < head.data:
        node.next = head
        node.next.prev = node
        head = node
        return head
    
    current = head
    while current.next and current.next.data < data:
            current = current.next
    
    
    if not current.next:
        current.next = node
        node.prev = current
    else:       
        node.next= current.next
        current.next = node
        node.next.prev = node
        node.prev = current
    
    return head

# %%
if __name__ == '__main__':

    t = 1

    for t_itr in range(t):
        llist_count = 3

        llist = DoublyLinkedList()
        
        #arr = [1,3,4,10]
        arr = [2,3,4]
        for i in range(llist_count):
            llist_item = arr[i]
            llist.insert_node(llist_item)

        data = 1

        llist1 = sortedInsert(llist.head, data)

        print_doubly_linked_list(llist1)

# %% [markdown]
# ### Insert a node at a specific position in a linked list

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

class SinglyLinkedListNode:
    def __init__(self, node_data):
        self.data = node_data
        self.next = None

class SinglyLinkedList:
    def __init__(self):
        self.head = None
        self.tail = None

    def insert_node(self, node_data):
        node = SinglyLinkedListNode(node_data)

        if not self.head:
            self.head = node
        else:
            self.tail.next = node


        self.tail = node

def print_singly_linked_list(node):
    while node:
        print(node.data)

        node = node.next


# Complete the insertNodeAtPosition function below.

#
# For your reference:
#
# SinglyLinkedListNode:
#     int data
#     SinglyLinkedListNode next
#
#
def insertNodeAtPosition(head, data, position):

#     if (not head) and (position == 0):
#         llist = SinglyLinkedList()
#         llist.insert_node(data)
#         return head
    
    node = SinglyLinkedListNode(data)
    
    i = 0
    
    current = head
    print(current is None)
    
    while i < position-1:
        current = current.next
        i += 1
    
    remain = current.next
    current.next = node
    node.next = remain
    return head
    
    
if __name__ == '__main__':
    #fptr = open(os.environ['OUTPUT_PATH'], 'w')

    llist_count = 3

    llist = SinglyLinkedList()

    arr=[16,13,7]
    for i in range(llist_count):
        llist_item = arr[i]
        llist.insert_node(llist_item)

    print_singly_linked_list(llist.head)
    
    data = 1

    position = 2

    llist_head = insertNodeAtPosition(llist.head, data, position)

    print_singly_linked_list(llist_head)
#     fptr.write('\n')

#     fptr.close()

# %% [markdown]
# ### Detect a Cycle
# - https://www.geeksforgeeks.org/detect-and-remove-loop-in-a-linked-list/
#     - remove loop:
#         - find the loop stat point, two pointer, one is in the loop, one is start from the head,

# %%
# M1  Floyd’s Cycle detection algorithm
# a slow pointer to next  and fast pointer to next.next
# def has_cycle(head):
    
#     if head is None:
#         return False
    
    
#     slow = head
#     fast = head.next
    
#     i = 0
#     while slow != fast:
#         i += 1
#         print(f"i")
#         if fast = None or fast.next = None:
#             return False
        
#         slow = slow.next
#         fast = fast.next.next
    
#     return True


# def has_cycle(head):
#     if head is None:
#         return False
    
#     s = set()
#     temp = head
#     while temp:
#         if temp in s:
#             return True
        
#         s.add(temp)
#         temp = temp.next
    
#     return False

def has_cycle(head)
    try:
        slow = head
        fast = head.next
        while slow is not fast:
            slow = slow.next
            fast = fast.next.next
        return True
    except:
        return False

# %% [markdown]
# ## Medium

# %% [markdown]
# ### 143. Reorder List
#
# ```
# Given a singly linked list L: L0→L1→…→Ln-1→Ln,
# reorder it to: L0→Ln→L1→Ln-1→L2→Ln-2→…
#
# You may not modify the values in the list's nodes, only nodes itself may be changed.
#
# Example 1:
#
# Given 1->2->3->4, reorder it to 1->4->2->3.
# Example 2:
#
# Given 1->2->3->4->5, reorder it to 1->5->2->4->3.
#
# ```

# %%
class Solution:
    def reorderList(self, head):
        """
        Do not return anything, modify head in-place instead.
        """
        head, middle = self.half_split(head)
        middle = self.reverse(middle)
        head = self.mergeTwo(head,middle)
        
    
    def half_split(self,head):
        
        if (head == None) or (head.next == None):
            return head
        
        slow = head
        fast = head
        while fast.next and fast.next.next:
            slow = slow.next
            fast = fast.next.next
        
        middle = slow.next        
        slow.next = None
        return head,middle
    
    def reverse(self,head):
        if (head == None) or (head.next == None):
            return head
        
        pre = None
        cur = head
        while cur:
            next_node = cur.next
            cur.next = pre
            pre = cur
            cur = next_node
        return pre
    
    def mergeTwo(self,head1,head2):
        
        cur1 = head1
        cur2 = head2
        while cur1 and cur2:
            next_cur1 = cur1.next
            next_cur2 = cur2.next
            cur1.next= cur2
            cur2.next = next_cur1
            
            cur1 = next_cur1
            cur2 = next_cur2
        
        return head1

# %%
if __name__ == '__main__':
    arr = [1,2,3,4,5,6,7]
    n = len(arr)
    
    slist = SingleLinkedList()
    for a in arr:
        slist.insert_node(slist.head,a)
    
    Solution().reorderList(slist.head)
    
    ans = print_linkedlist(slist.head)
    print(ans)
# Out:
# [1, 7, 2, 6, 3, 5, 4]

# %%
# test case
if __name__ == '__main__':
    arr = [1,2,3,4,5]
    n = len(arr)
    
    slist = SingleLinkedList()
    for a in arr:
        slist.insert_node(slist.head,a)
    
    Solution().reorderList(slist.head)
    
    ans = reorderList(slist.head)
    print(ans)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-3a8b75b50e7c> in <module>()
#      10     Solution().reorderList(slist.head)
#      11
# ---> 12     ans = reorderList(slist.head)
#      13     print(ans)
#
# NameError: name 'reorderList' is not defined

# %% [markdown]
# ### 148. Sort List
#
# ```
# Sort a linked list in O(n log n) time using constant space complexity.
#
# Example 1:
#
# Input: 4->2->1->3
# Output: 1->2->3->4
# Example 2:
#
# Input: -1->5->3->4->0
# Output: -1->0->3->4->5
#
# ```

# %%
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, x):
#         self.val = x
#         self.next = None

class Solution:
    def sortList(self, head):
        if (head == None) or (head.next == None):
            return head
        
        
        # Split a list from mid
        mid = self.findMid(head)
        l1 = head
        l2 = mid.next
        mid.next = None
        
        l1 = self.sortList(l1)
        l2 = self.sortList(l2)
        
        return self.merge(l1,l2)
        
    
    
    def merge(self,l1,l2):
        
        if l1 is None:
            return l2
        if l2 is None:
            return l1
        
        dummy = Node(-1)
        cur = dummy
        
        while l1 and l2:
            if l1.val <=l2.val:
                cur.next = l1
                l1 = l1.next
            else:
                cur.next = l2
                l2 = l2.next
            cur = cur.next
            
        if l1:
            cur.next = l1
        else:
            cur.next = l2
        
        return dummy.next

    
    def findMid(self,head):
        if (head == None) or (head.next == None):
            return head
        
        slow = head
        fast = head
        
        while fast.next and fast.next.next:
            slow = slow.next
            fast = fast.next.next
        
        return slow

# %%
if __name__ == '__main__':
    arr = [3,2,1,4,5,4]
    n = len(arr)
    
    slist = SingleLinkedList()
    for a in arr:
        slist.insert_node(slist.head,a)
    
    obj = Solution()
    ans = obj.sortList(slist.head)
    ans = print_linkedlist(ans)
    print(ans)
# Out:
# [1, 2, 3, 4, 4, 5]

# %% [markdown]
# ### [ ] 817. Linked List Components
#
# ```
# We are given head, the head node of a linked list containing unique integer values.
#
# We are also given the list G, a subset of the values in the linked list.
#
# Return the number of connected components in G, where two values are connected if they appear consecutively in the linked list.
#
# Example 1:
#
# Input:
# head: 0->1->2->3
# G = [0, 1, 3]
# Output: 2
# Explanation:
# 0 and 1 are connected, so [0, 1] and [3] are the two connected components.
# Example 2:
#
# Input:
# head: 0->1->2->3->4
# G = [0, 3, 1, 4]
# Output: 2
# Explanation:
# 0 and 1 are connected, 3 and 4 are connected, so [0, 1] and [3, 4] are the two connected components.
# ```

# %%
class Solution:
    def numComponents(head, G):

# %% [markdown]
# ### 1019. Next Greater Node In Linked List
#
# ```
# We are given a linked list with head as the first node.  Let's number the nodes in the list: node_1, node_2, node_3, ... etc.
#
# Each node may have a next larger value: for node_i, next_larger(node_i) is the node_j.val such that j > i, node_j.val > node_i.val, and j is the smallest possible choice.  If such a j does not exist, the next larger value is 0.
#
# Return an array of integers answer, where answer[i] = next_larger(node_{i+1}).
#
# Note that in the example inputs (not outputs) below, arrays such as [2,1,5] represent the serialization of a linked list with a head node value of 2, second node value of 1, and third node value of 5.
#
#
#
# Example 1:
#
# Input: [2,1,5]
# Output: [5,5,0]
# Example 2:
#
# Input: [2,7,4,3,5]
# Output: [7,0,5,5,0]
# Example 3:
#
# Input: [1,7,5,1,9,2,5,1]
# Output: [7,9,9,9,0,5,0,0]
#
# ```

# %%
class Solution(object):

# M1: brute-force, time limit exceeded    
#     def nextLargerNodes(self, head):
#         """
#         :type head: ListNode
#         :rtype: List[int]
#         """
        
#         ans = []
#         cur  = head
#         while cur:
#             next_node = cur.next
#             while next_node:
#                 if next_node.val > cur.val:
#                     ans.append(next_node.val)
#                     break
#                 else:
#                     next_node = next_node.next
#             if next_node is None:
#                 ans.append(0)
#             cur = cur.next
#         return ans
    
    def nextLargerNodes(self, head):
        ans = []
        stack = []
        cur = head
        while cur:
            while stack and stack[-1][1] < cur.val:
                ans[stack.pop()[0]] = cur.val            
            
            stack.append([len(ans),cur.val])  # take the length of answer as the index
            ans.append(0)
            cur = cur.next
        return ans

# %%
# test case
if __name__ == '__main__':
    arr = [1,7,5,1,9,2,5,1]
    n = len(arr)
    
    slist = SingleLinkedList()
    for a in arr:
        slist.insert_node(slist.head,a)
    
    obj = Solution()
    
    
    ans = obj.nextLargerNodes(slist.head)
    print(ans)
# Out:
# [7, 9, 9, 9, 0, 5, 0, 0]

# %% [markdown]
# ### 138. Copy List with Random Pointer
#
# ```
# A linked list is given such that each node contains an additional random pointer which could point to any node in the list or null.
#
# Return a deep copy of the list.
#
#
#
# Example 1:
#
#
#
# Input:
# {"$id":"1","next":{"$id":"2","next":null,"random":{"$ref":"2"},"val":2},"random":{"$ref":"2"},"val":1}
#
# Explanation:
# Node 1's value is 1, both of its next and random pointer points to Node 2.
# Node 2's value is 2, its next pointer points to null and its random pointer points to itself.
#
#
# Note:
#
# You must return the copy of the given head as a reference to the cloned list.
#
# ```

# %%
class Solution(object):
    def copyRandomList(self, head):
        """
        :type head: Node
        :rtype: Node
        """
        
        m = n = head
        
        #map origin node to new node
        copy_dict = {}
        while m:
            copy_dict[m] = Node(m.val)
            m = m.next
        
        while n:
            # only can use dict.get not dict[],because 
            copy_dict[n].next = copy_dict.get(n.next)
            copy_dict[n].random = copy_dict.get(n.random)
            n = n.next
        
        return copy_dict.get(head)

# %% [markdown]
# ### 92. Reverse Linked List II
#
# ```
# Reverse a linked list from position m to n. Do it in one-pass.
#
# Note: 1 ≤ m ≤ n ≤ length of list.
#
# Example:
#
# Input: 1->2->3->4->5->NULL, m = 2, n = 4
# Output: 1->4->3->2->5->NULL
# ```

# %%
def reverseBetween(head, m, n):
    if m == 1:
        prev = None
        current = head
        i = 0
        while i < n:
            next_node = current.next
            current.next = prev
            prev = current
            current = next_node
            i +=1
        head.next = current   
        return prev
    else:
        prevm = head
        j = 1
        while j < n+1:
            if j < m -1:
                prevm = prevm.next           
            elif j == m-1:
                prev = prevm 
                mnode = prev.next
                current = mnode
            else:
                next_node = current.next
                current.next = prev
                prev = current
                current = next_node            
            j += 1
        mnode.next = current
        prevm.next = prev
        return head

# %%
if __name__ == '__main__':
    arr = [1,2,3,4,5,6]
    n = len(arr)
    
    slist = SingleLinkedList()
    for a in arr:
        slist.insert_node(slist.head,a)
    
    reversehead = reverseBetween(slist.head,2,5)
    ans = print_linkedlist(reversehead)
    print(ans)
# Out:
# [1, 5, 4, 3, 2, 6]

# %% [markdown]
# ### 24. Swap Nodes in Pairs

# %%
# M1:Recusive
def swapPairs1(head):
    if head is None:
        return None
    if head.next is None:
        return head
    
    tmp = head.next
    head.next = swapPairs(tmp.next)
    tmp.next = head
    return tmp

# %%
def swapPairs2(head):
    
    if (head is None) or (head.next is None):
        return head
    
    dummy = Node(-1)
    dummy.next = head
    
    cur = dummy
    
    while cur.next and cur.next.next:
        next1, next2, next3 = cur.next, cur.next.next, cur.next.next.next
        cur.next = next2
        next1.next = next3
        next2.next = next1
        cur = next1
    return dummy.next

# %%
if __name__ == '__main__':
    arr = [1,2,3,4,5,6,7]
    n = len(arr)
    
    slist = SingleLinkedList()
    for a in arr:
        slist.insert_node(slist.head,a)
    
    ans_head = swapPairs2(slist.head)
    ans = print_linkedlist(ans_head)
    print(ans)
# Out:
# [2, 1, 4, 3, 6, 5, 7]

# %%
2%2
# Out:
# 0

# %% [markdown]
# ## Hard

# %% [markdown]
# ### [ ] 23. Merge k Sorted Lists
#
# - https://github.com/apachecn/Interview/blob/master/docs/Algorithm/Leetcode/Python/023._merge_k_sorted_lists.md
# ```
# Merge k sorted linked lists and return it as one sorted list. Analyze and describe its complexity.
#
# Example:
#
# Input:
# [
#   1->4->5,
#   1->3->4,
#   2->6
# ]
# Output: 1->1->2->3->4->4->5->6
#
# ```

# %%
class Solution(object):
    def mergeKLists(self, lists):
        """
        :type lists: List[ListNode]
        :rtype: ListNode
        """
